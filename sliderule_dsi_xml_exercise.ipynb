# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %%
import pandas as pd

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './mondial_database.xml' )

# %%
root = document.getroot()

# %%
# find names of all countries and their gdp and save as DataFrame
gdp_total = pd.DataFrame()
for element in document.iterfind('country'):
    #print('* ' + element.find('name').text + ':')
    data_string = ''
    for subelement in element.getiterator('gdp_total'):
        data_string = element.find('gdp_total').text
    if(data_string == ''):
        data_string = 'NaN'
    #print(element.find('name').text + ': ' + data_string[:])
    temp = pd.DataFrame({'Country':[element.find('name').text],
                         'GDP_Total':[float(data_string[:])]})
    gdp_total = gdp_total.append(temp, ignore_index = True)
gdp_total
# Out:
#                     Country  GDP_Total
# 0                   Albania    12800.0
# 1                    Greece   243300.0
# 2                 Macedonia    10650.0
# 3                    Serbia    43680.0
# 4                Montenegro     4518.0
# 5                    Kosovo     7150.0
# 6                   Andorra     4800.0
# 7                    France  2739000.0
# 8                     Spain  1356000.0
# 9                   Austria   417900.0
# 10           Czech Republic   194800.0
# 11                  Germany  3593000.0
# 12                  Hungary   130600.0
# 13                    Italy  2068000.0
# 14            Liechtenstein     5113.0
# 15                 Slovakia    96960.0
# 16                 Slovenia    46820.0
# 17              Switzerland   646200.0
# 18                  Belarus    69240.0
# 19                   Latvia    30380.0
# 20                Lithuania    46710.0
# 21                   Poland   513900.0
# 22                  Ukraine   175500.0
# 23                   Russia  2113000.0
# 24                  Belgium   507400.0
# 25               Luxembourg    60540.0
# 26              Netherlands   722300.0
# 27   Bosnia and Herzegovina    18870.0
# 28                  Croatia    59140.0
# 29                 Bulgaria    53700.0
# ..                      ...        ...
# 214                    Chad    13590.0
# 215       Equatorial Guinea    17080.0
# 216                   Gabon    19970.0
# 217              Cape Verde     1955.0
# 218                   Sudan    52500.0
# 219             South Sudan    11770.0
# 220                 Comoros      658.0
# 221                  Guinea     6544.0
# 222                 Liberia     1977.0
# 223                Djibouti     1459.0
# 224                 Eritrea     3438.0
# 225                Ethiopia    47340.0
# 226                 Somalia     2372.0
# 227                   Kenya    45310.0
# 228                  Gambia      896.0
# 229                 Senegal    15360.0
# 230           Guinea-Bissau      880.0
# 231            Sierra Leone     4607.0
# 232                  Uganda    22600.0
# 233                 Lesotho     2457.0
# 234              Madagascar    10530.0
# 235                  Malawi     3683.0
# 236              Mozambique    14670.0
# 237               Mauritius    11900.0
# 238                 Mayotte      953.6
# 239               Swaziland     3807.0
# 240                 Reunion     2900.0
# 241            Saint Helena       18.0
# 242   Sao Tome and Principe      311.0
# 243              Seychelles     1271.0
#
# [244 rows x 2 columns]

# %%
#save names of all countries and their infant mortality rates
#storage df
infant_mortality = pd.DataFrame()
#iterate elements in tree document
for element in document.iterfind('country'):
    
    #initialize inf_mort text string for output of query
    inf_mort = ''
    
    #find appropriate subelements and appends to text string if exists
    for subelement in element.getiterator('infant_mortality'):
        inf_mort += element.find('infant_mortality').text
    #print(element.find('name').text + ': ' + inf_mort[:])
    
    #check in the case that no value was found and replace '' with 'NaN'
    if(inf_mort == ''):
        inf_mort = 'NaN'
    
    #save found data to a temp df, and convert inf_mort string to a float
    temp = pd.DataFrame({'Country':[element.find('name').text],
                         'Infant_Mortality':[float(inf_mort[:])]})
    
    #append temp df to infant_mortality df
    infant_mortality = infant_mortality.append(temp,ignore_index = True)

#print out top-1o sorted results
print(infant_mortality.nsmallest(10,'Infant_Mortality'))

print(infant_mortality.nlargest(10,'Infant_Mortality'))
# Out:
#             Country  Infant_Mortality
# 38           Monaco              1.81
# 98            Japan              2.13
# 36           Norway              2.48
# 117         Bermuda              2.48
# 36           Norway              2.48
# 117         Bermuda              2.48
# 106       Singapore              2.53
# 37           Sweden              2.60
# 10   Czech Republic              2.63
# 78        Hong Kong              2.73
# 79            Macao              3.13
# 44          Iceland              3.15
#                       Country  Infant_Mortality
# 194            Western Sahara            145.82
# 54                Afghanistan            117.23
# 189                      Mali            104.34
# 226                   Somalia            100.14
# 213  Central African Republic             92.86
# 230             Guinea-Bissau             90.92
# 214                      Chad             90.30
# 192                     Niger             86.27
# 195                    Angola             79.99
# 201              Burkina Faso             76.80

# %%
# print names of all countries and all measured populations
for element in document.iterfind('country'):
    #print('* ' + element.find('name').text + ':')
    pop_num = []
    #pop_yrs = []
    for subelement in element.getiterator('population'):
        pop_num = element.findall('population')
    #    pop_yrs = element.findall('year')
    #for element in data_list
    print("* " + element.find('name').text)
    for element in pop_num:
        print(element.text," - ", element.attrib['year'])
# Out:
# * Albania
# 1214489  -  1950
# 1618829  -  1960
# 2138966  -  1970
# 2734776  -  1980
# 3446882  -  1990
# 3249136  -  1997
# 3304948  -  2000
# 3069275  -  2001
# 2800138  -  2011
# * Greece
# 1096810  -  1861
# 1457894  -  1870
# 1679470  -  1879
# 2433806  -  1896
# 2631592  -  1907
# 5016889  -  1920
# 6204684  -  1928
# 7344860  -  1940
# 7632801  -  1951
# 8388553  -  1961
# 8768372  -  1971
# 9739589  -  1981
# 10217335  -  1991
# 10934097  -  2001
# 10816286  -  2011
# * Macedonia
# 808724  -  1921
# 949958  -  1931
# 1152986  -  1948
# 1304514  -  1953
# 1406003  -  1961
# 1647308  -  1971
# 1909136  -  1981
# 2033964  -  1991
# 1935034  -  1994
# 2022547  -  2002
# 2059794  -  2011
# * Serbia
# 6732256  -  1950
# 7657958  -  1960
# 8236185  -  1970
# 9057483  -  1980
# 9735429  -  1990
# 7620531  -  1991
# 7498001  -  2002
# 7120666  -  2011
# * Montenegro
# 311341  -  1921
# 360044  -  1931
# 377189  -  1948
# 419873  -  1953
# 471894  -  1961
# 529604  -  1971
# 584310  -  1981
# 615035  -  1991
# 620145  -  2003
# 620029  -  2011
# * Kosovo
# 1584440  -  1981
# 1956196  -  1991
# 1733872  -  2011
# * Andorra
# 6197  -  1950
# 13414  -  1960
# 24279  -  1970
# 36063  -  1980
# 46166  -  1989
# 66334  -  2001
# 81222  -  2006
# 78115  -  2011
# * France
# 40502513  -  1946
# 42777162  -  1954
# 46520271  -  1962
# 49778540  -  1968
# 52591584  -  1975
# 54334871  -  1982
# 56615155  -  1990
# 81755  -  2002
# 90945  -  2010

# %% [markdown]
# # print names of all cities and all measured populations
# for element in document.iterfind('country'):
#     city_name = ''
#     pop_num = []
#     city_pop_all = []
#
#
#
#     #some countries are divided into "Provinces" before "Cities"
#     for subelement in element.iter('province'):
#         for subsubelement in subelement.iter('city'):
#             city_name     = subsubelement.find('name').text
#             city_pop_all  = subsubelement.findall('population')
#
#             city_pop_last = ''
#             city_pop_year = ''
#             if(len(city_pop_all )== 0):
#                 city_pop_last = 'NaN'
#                 city_pop_year = 'NaN'
#             else:
#                 city_pop_last = city_pop_all[-1].text
#                 city_pop_year = city_pop_all[-1].attrib['year']
#
#             print(element.find('name').text +
#                   ' : '+ city_name +
#                   ' - '+ city_pop_last +
#                   ' (' + city_pop_year +')')

# %% [markdown]
# for element in document.iterfind('country'):
#     for subelement in element.iterfind('city'):#print(element)
#         city_name = subelement.find('name').text
#         city_pop_all  = subelement.findall('population')
#
#         city_pop_last = ''
#         city_pop_year = ''
#         if(len(city_pop_all) == 0):
#             city_pop_last = 'NaN'
#             city_pop_year = 'NaN'
#         else:
#             city_pop_last = city_pop_all[-1].text
#             city_pop_year = city_pop_all[-1].attrib['year']
#
#         print(element.find('name').text +
#                   ' : '+ city_name +
#                   ' - '+ city_pop_last +
#                   ' ('+ city_pop_year +')')
#         #print(element.find('name').text +' : '+ city_name)

# %% [markdown]
# # find and save names of all cities and all measured populations
# #initialize empty storage dataframe
# city_population = pd.DataFrame()
#
# for element in document.iterfind('country'):
#
#     #reset indiviudal storage variable
#     city_name = ''
#     pop_num = []
#     city_pop_all = []
#
#     #some countries list cities as a direct sub-element
#     for subelement in element.iterfind('city'):
#
#         #find city
#         city_name = subelement.find('name').text
#         city_pop_all  = subelement.findall('population')
#
#         city_pop_last = ''
#         city_pop_year = ''
#         if(len(city_pop_all) == 0):
#             city_pop_last = float('NaN')
#             city_pop_year = float('NaN')
#         else:
#             city_pop_last = int(city_pop_all[-1].text)
#             city_pop_year = int(city_pop_all[-1].attrib['year'])
#
#         temp = pd.DataFrame({'Country':[element.find('name').text],
#                              'City_Name':[city_name],
#                              'City_Pop':[city_pop_last],
#                              'Pop_Year':[city_pop_year]})
#
#         city_population = city_population.append(temp, ignore_index=True)
#
#
#     #some countries are divided into "Provinces" before "Cities"
#     for subelement in element.iter('province'):
#         for subsubelement in subelement.iter('city'):
#             city_name     = subsubelement.find('name').text
#             city_pop_all  = subsubelement.findall('population')
#
#             city_pop_last = ''
#             city_pop_year = ''
#             if(len(city_pop_all )== 0):
#                 city_pop_last = float('NaN')
#                 city_pop_year = float('NaN')
#             else:
#                 city_pop_last = int(city_pop_all[-1].text)
#                 city_pop_year = int(city_pop_all[-1].attrib['year'])
#
#             temp = pd.DataFrame({'Country':[element.find('name').text],
#                              'City_Name':[city_name],
#                              'City_Pop':[city_pop_last],
#                              'Pop_Year':[city_pop_year]})
#
#             city_population = city_population.append(temp, ignore_index=True)
#
# #print the 10 largest cities in terms of population
# #print(city_population.nlargest(10,'City_Pop'))
# #print(city_population.nsmallest(10,'City_Pop'))
# city_population

# %%
#function for city population
#input is name of country and city subelement
#code finds the city name, population, year of population and formats
#output is a df with country name, city name, population, population year

def pop_finder(country_name, inp_element):
    
    #find city
    city_name = inp_element.find('name').text
    city_pop_all  = inp_element.findall('population')
        
    city_pop_last = ''
    city_pop_year = ''
    if(len(city_pop_all) == 0):
        city_pop_last = float('NaN')
        city_pop_year = float('NaN')
    else:
        city_pop_last = int(city_pop_all[-1].text)
        city_pop_year = int(city_pop_all[-1].attrib['year'])
        
    temp = pd.DataFrame({'Country':[country_name],
                         'City_Name':[city_name],
                         'City_Pop':[city_pop_last],
                         'Pop_Year':[city_pop_year]})
    
    return temp

# %%
# find and save names of all cities and all measured populations
#initialize empty storage dataframe
city_population3 = pd.DataFrame()

for element in document.iterfind('country'):
    
    #reset indiviudal storage variable
    city_name = ''
    pop_num = []
    city_pop_all = []
    
    #some countries list cities as a direct sub-element
    for subelement in element.iterfind('city'):
        
        country_name = element.find('name').text
        new_row = pop_finder(country_name, subelement)
        city_population3 = city_population3.append(new_row, ignore_index=True)
        
        
    #some countries are divided into "Provinces" before "Cities"
    for subelement in element.iterfind('./province/city'):
        #for subsubelement in subelement.iter('city'):
        country_name = element.find('name').text
        new_row = pop_finder(country_name, subelement)
        city_population3 = city_population3.append(new_row, ignore_index=True)

#print the 10 largest cities in terms of population
print(city_population3.nlargest(10,'City_Pop'))
print(city_population3.nsmallest(10,'City_Pop'))
# Out:
#       City_Name    City_Pop Country  Pop_Year
# 1341   Shanghai  22315474.0   China    2010.0
# 771    Istanbul  13710512.0  Turkey    2012.0
# 1527     Mumbai  12442373.0   India    2011.0
# 479      Moskva  11979529.0  Russia    2013.0
# 1340    Beijing  11716620.0   China    2010.0
# 2810  São Paulo  11152344.0  Brazil    2010.0
# 1342    Tianjin  11090314.0   China    2010.0
# 1064  Guangzhou  11071424.0   China    2010.0
# 1582      Delhi  11034555.0   India    2011.0
# 1067   Shenzhen  10358381.0   China    2010.0
#          City_Name  City_Pop           Country  Pop_Year
# 436        Prypjat       0.0           Ukraine    2001.0
# 2497      Plymouth       0.0        Montserrat    2009.0
# 436        Prypjat       0.0           Ukraine    2001.0
# 2497      Plymouth       0.0        Montserrat    2009.0
# 27          Karyes     233.0            Greece    2014.0
# 2600      Melekeok     391.0             Palau    2009.0
# 2605       Fakaofo     490.0           Tokelau    2011.0
# 862   Hermannsverk     706.0            Norway    1987.0
# 906   Vatican City     842.0          Holy See    2014.0
# 903         Monaco     975.0            Monaco    2008.0
# 2499   Philipsburg    1338.0      Sint Maarten    2006.0
# 2501      Gustavia    2299.0  Saint Barthelemy    2006.0

# %% [markdown]
# # find and save names of all cities and all measured populations
# #initialize empty storage dataframe
# city_population2 = pd.DataFrame()
#
# for element in document.iterfind('country'):
#
#     #reset indiviudal storage variable
#     city_name = ''
#     pop_num = []
#     city_pop_all = []
#
#     #some countries list cities as a direct sub-element
#     for subelement in element.iterfind('city'):
#
#         #find city
#         city_name = subelement.find('name').text
#         city_pop_all  = subelement.findall('population')
#
#         city_pop_last = ''
#         city_pop_year = ''
#         if(len(city_pop_all) == 0):
#             city_pop_last = float('NaN')
#             city_pop_year = float('NaN')
#         else:
#             city_pop_last = int(city_pop_all[-1].text)
#             city_pop_year = int(city_pop_all[-1].attrib['year'])
#
#         temp = pd.DataFrame({'Country':[element.find('name').text],
#                              'City_Name':[city_name],
#                              'City_Pop':[city_pop_last],
#                              'Pop_Year':[city_pop_year]})
#
#         city_population2 = city_population2.append(temp, ignore_index=True)
#
#
#     #some countries are divided into "Provinces" before "Cities"
#     for subelement in element.iterfind('./province/city'):
#         #for subsubelement in subelement.iter('city'):
#         city_name     = subelement.find('name').text
#         city_pop_all  = subelement.findall('population')
#
#         city_pop_last = ''
#         city_pop_year = ''
#         if(len(city_pop_all )== 0):
#             city_pop_last = float('NaN')
#             city_pop_year = float('NaN')
#         else:
#             city_pop_last = int(city_pop_all[-1].text)
#             city_pop_year = int(city_pop_all[-1].attrib['year'])
#
#         temp = pd.DataFrame({'Country':[element.find('name').text],
#                              'City_Name':[city_name],
#                              'City_Pop':[city_pop_last],
#                              'Pop_Year':[city_pop_year]})
#
#         city_population2 = city_population2.append(temp, ignore_index=True)
#
# #print the 10 largest cities in terms of population
# city_population2

# %%
#save data to DataFrame
eth_groups = pd.DataFrame()

for element in document.iterfind('country'):
#    eth_grp = []
#    for subelement in element.iter('ethnicgroup'):
    eth_grp = element.findall('ethnicgroup')
    pop_num = element.findall('population')
            
    print("* " + element.find('name').text +
          ' : '+ pop_num[-1].text +
          ' ('+ pop_num[-1].attrib['year']+')')
    
    for element in eth_grp:
        print('  ' + element.text + " - " + element.attrib['percentage'])
    
#        temp = pd.DataFrame(
#            {"Country":[element.find('name').text],
#             "Ethnic_Group":[eth_grp[-1].text],
#             "Percentage":[int(float(eth_grp[-1].attrib['percentage']))]})
        
#        eth_groups = eth_groups.append(temp, ignore_index=True)
#eth_groups
# Out:
# * Albania : 2800138 (2011)
#   Albanian - 95
#   Greek - 3
# * Greece : 10816286 (2011)
#   Greek - 93
# * Macedonia : 2059794 (2011)
#   Macedonian - 64.2
#   Albanian - 25.2
#   Turkish - 3.9
#   Gypsy - 2.7
#   Serb - 1.8
# * Serbia : 7120666 (2011)
#   Serb - 82.9
#   Montenegrin - 0.9
#   Hungarian - 3.9
#   Roma - 1.4
#   Bosniak - 1.8
#   Croat - 1.1
# * Montenegro : 620029 (2011)
#   Montenegrin - 43
#   Serb - 32
#   Bosniak - 8
#   Albanian - 5
# * Kosovo : 1733872 (2011)
#   Albanian - 92
#   Serbian - 5
# * Andorra : 78115 (2011)
#   Spanish - 43
#   Andorran - 33
#   Portuguese - 11
#   French - 2
#   African - 5
# * France : 64933400 (2011)
# * Spain : 46815916 (2011)
#   Mediterranean Nordic - 100
# * Austria : 8499759 (2013)
#   Austrian - 91.1
#   Turkish - 1.6
#   Slovene - 1
#   Croat - 2
#   Serbs - 2
#   German - 0.9
# * Czech Republic : 10562214 (2011)
#   Czech - 90.4
#   Moravian - 3.7
#   Slovak - 1.9
#   German - 0.5
#   Polish - 0.6
#   Roma - 0.3
#   Hungarian - 0.2
# * Germany : 80219695 (2011)
#   German - 91.5
#   Turkish - 2.4
# * Hungary : 9937628 (2011)
#   Hungarian - 92.3
#   Roma - 1.9
#   Serb - 2
#   German - 2.6
#   Slovak - 0.8
#   Romanian - 0.7
# * Italy : 59433744 (2011)
# * Liechtenstein : 36636 (2012)
#   Italian - 5
#   Alemannic - 95
# * Slovakia : 5397036 (2011)
#   Slovak - 85.7
#   Hungarian - 9.7
#   Roma - 1.7
#   Czech - 1
#   Ukrainian - 0.3
#   Ruthenian - 0.3
#   German - 0.1
#   Polish - 0.1
# * Slovenia : 2058821 (2013)
#   Slovene - 91
#   Croat - 3
#   Serb - 2
#   Bosniak - 1
# * Switzerland : 8139631 (2013)
#   German - 65
#   French - 18
#   Italian - 10
#   Romansch - 1
# * Belarus : 9460692 (2013)
#   Belorussian - 81.2
#   Russian - 11.4
#   Polish - 3.9
#   Ukrainian - 2.4
# * Latvia : 2201196 (2013)
#   Latvian - 59.3
#   Russian - 27.8
#   Belorussian - 3.6
#   Ukrainian - 2.5
#   Polish - 2.4
#   Lithuanian - 1.3
# * Lithuania : 2979310 (2013)
#   Lithuanian - 84
#   Polish - 6.1
#   Russian - 4.9
#   Belorussian - 1.1
# * Poland : 38533789 (2012)
#   German - 1.3
#   Polish - 97.6
#   Ukrainian - 0.6
#   Byelorussian - 0.5
# * Ukraine : 45633637 (2012)
#   Ukrainian - 77.8
#   Russian - 17.3
#   Belorussian - 0.6
#   Moldovan - 0.5
#   Crimean Tatar - 0.5
#   Bulgarian - 0.4
#   Hungarian - 0.3
#   Romanian - 0.3
#   Polish - 0.3
#   Jewish - 0.2
# * Russia : 143666931 (2014)
#   Russian - 79.8
#   Tatar - 3.8
#   Ukrainian - 2
#   Bashkir - 1.2
#   Chuvash - 1.1
# * Belgium : 11099554 (2013)
#   Fleming - 58
#   Walloon - 31
# * Luxembourg : 524853 (2012)
#   Luxembourgish - 63.1
#   Portuguese - 13.3
#   French - 4.5
#   Italian - 4.3
#   German - 2.3
# * Netherlands : 16843181 (2014)
#   Dutch - 80.7
#   Indonesian - 2.4
#   Turkish - 2.2
#   Moroccan - 2
#   Surinamese - 2
#   Caribbean - 0.8
# * Bosnia and Herzegovina : 3791622 (2013)
#   Muslim - 48
#   Bosniak - 37.1
#   Croat - 14.3
# * Croatia : 4290612 (2011)
#   Croat - 89.6
#   Serb - 4.5
#   Hungarian - 0.5
#   Muslim - 0.9
#   Slovene - 0.5
# * Bulgaria : 7284552 (2012)
#   Bulgarian - 76.9
#   Turkish - 8
#   Roma - 4.4
#   Macedonian - 2.5
#   Russian - 0.2
#   Armenian - 0.3
# * Romania : 20121641 (2011)
#   Romanian - 89.1
#   Hungarian - 6.6
#   Roma - 2.5
#   German - 0.3
#   Ukrainian - 0.3
#   Russian - 0.2
#   Turkish - 0.2
# * Turkey : 75627384 (2012)
#   Turkish - 84.54
#   Kurdish - 11.97
#   Arabic - 1.38
# * Denmark : 5580516 (2012)
# * Estonia : 1294455 (2011)
#   Estonian - 68.7
#   Russian - 25.6
#   Ukrainian - 2.1
#   Belorussian - 1.2
#   Finn - 0.8
# * Faroe Islands : 48197 (2013)
#   Scandinavian - 100
# * Finland : 5455068 (2014)
#   Finn - 93.4
#   Swede - 5.6
#   Russian - 0.5
#   Estonian - 0.3
# * Norway : 5051275 (2013)
#   Norwegian - 82.5
#   Sami - 1.5
# * Sweden : 9555893 (2012)
#   Swede - 83
#   Finn - 5
# * Monaco : 36845 (2010)
#   French - 47
#   Monegasque - 21.6
#   Italian - 19
# * Gibraltar : 27495 (2011)
# * Guernsey : 59807 (2001)
#   Norman-French - 100
# * Holy See : 842 (2014)
# * Ceuta : 82376 (2011)
# * Melilla : 78476 (2011)
# * Iceland : 318452 (2011)
#   Celt - 100
# * Ireland : 4588252 (2011)
#   Irish - 87.4
#   Asian - 1.3
#   African - 1.1
# * San Marino : 32440 (2012)
# * Jersey : 97857 (2011)
#   Norman-French - 100
# * Malta : 417432 (2011)
# * Isle of Man : 84497 (2011)
# * Moldova : 3559541 (2012)
#   Moldavian/Romanian - 78.2
#   Ukrainian - 8.4
#   Russian - 5.8
#   Gagauz - 4.4
#   Bulgarian - 1.9
# * Portugal : 10561614 (2011)
# * Svalbard : 1872 (2014)
#   Norwegian - 55.4
#   Russian Ukrainian - 44.3
# * United Kingdom : 64105654 (2013)
#   English - 83.6
#   Scottish - 8.6
#   Welsh - 4.9
#   Northern Irish - 2.9
#   African - 2
#   Indian - 1.8
#   Pakistani - 1.3
# * Afghanistan : 26023100 (2013)
#   Tajik - 25
#   Pashtun - 38
#   Uzbek - 6
#   Hazara - 19
# * China : 1360720000 (2013)
#   Han Chinese - 91.5
# * Iran : 75149669 (2011)
#   Arab - 3
#   Persian - 51
#   Baloch - 2
#   Azerbaijani - 24
#   Kurd - 7
#   Lur - 2
#   Turkmen - 2
#   Gilaki Mazandarani - 8
# * Pakistan : 173149306 (2010)
# * Tajikistan : 8161100 (2014)
#   Tajik - 79.9
#   Uzbek - 15.3
#   Russian - 1.1
#   Kyrgyz - 1.1
# * Turkmenistan : 5041995 (2010)
#   Turkmen - 85
#   Uzbek - 5
#   Russian - 4
# * Uzbekistan : 27769270 (2010)
#   Uzbek - 80
#   Russian - 5.5
#   Tajik - 5
#   Kazak - 3
#   Karakalpak - 2.5
#   Tatar - 1.5
# * Armenia : 3026879 (2013)
#   Armenian - 97.7
#   Russian - 0.5
#   Yezidi - 1.3
# * Georgia : 4483800 (2013)
#   Georgian - 83.8
#   Azeri - 6.5
#   Russian - 1.5
# * Azerbaijan : 9356500 (2013)
#   Azeri - 90.6
#   Dagestani - 2.2
#   Russian - 1.8
#   Armenian - 1.5
# * Bahrain : 1234596 (2010)
#   Arab - 10
#   Asian - 13
#   Bahraini - 63
#   Iranian - 8
# * Bangladesh : 149772364 (2011)
#   Bengali - 98
# * Myanmar : 51419420 (2014)
#   Indian - 2
#   Chinese - 3
#   Burman - 68
#   Shan - 9
#   Karen - 7
#   Rakhine - 4
#   Mon - 2
# * India : 1210854977 (2011)
#   Dravidian - 25
#   Indo-Aryan - 72
#   Mongol - 3
# * Bhutan : 733004 (2013)
#   Bhote - 50
#   Nepalese - 35
# * Brunei : 393372 (2011)
#   Chinese - 20
#   Malay - 64
# * Malaysia : 27565821 (2010)
#   Malay - 50.4
#   Chinese - 23.7
#   Indian - 7.1
#   Borneo indigenous - 11
# * Laos : 6514432 (2012)
#   Lao Loum - 68
#   Lao Theung - 22
#   Lao Soung Hmong Yao - 9
#   Vietnamese/Chinese - 1
# * Thailand : 65981659 (2010)
#   Chinese - 14
#   Thai - 75
# * Cambodia : 14364931 (2010)
#   Chinese - 1
#   Khmer - 90
#   Vietnamese - 5
# * Vietnam : 88772900 (2012)
#   Viet/Kinh - 85.7
#   Tay - 1.9
#   Thai - 1.8
#   Muong - 1.5
#   Khmer - 1.5
#   Mong - 1.2
#   Nung - 1.1
# * Kazakhstan : 17165239 (2014)
#   Kazakh - 63.1
#   Russian - 23.7
#   Uzbek - 2.8
#   Ukrainian - 2.1
#   Uighur - 1.4
#   Tatar - 1.3
#   German - 1.1
# * North Korea : 24500520 (2010)
# * Kyrgyzstan : 5776600 (2014)
#   Kyrgyz - 64.9
#   Uzbek - 13.8
#   Russian - 12.5
#   Dungan - 1.1
#   Ukrainian - 1
#   Uighur - 1
# * Hong Kong : 7071576 (2011)
#   Chinese - 95
#   Filipino - 1.6
#   Indonesian - 1.3
# * Macao : 552503 (2011)
#   Chinese - 95
#   Portuguese - 3
# * Mongolia : 2754685 (2010)
#   Mongol - 94.9
#   Kazak - 5
# * Nepal : 26494504 (2011)
# * Christmas Island : 2072 (2011)
#   Chinese - 70
#   Malay - 10
#   European - 20
# * Cocos Islands : 596 (2010)
# * Cyprus : 840407 (2011)
#   Greek - 77
#   Turkish - 18
# * Gaza Strip : 1760037 (2014)
#   Jewish - 0.6
#   Palestinian Arab - 99.4
# * Israel : 7420368 (2010)
#   Jewish - 76.4
#   Arab - 23
# * Egypt : 83667047 (2013)
#   European - 1
#   Eastern Hamitic - 99
# * Indonesia : 252124458 (2014)
#   Javanese - 45
#   Sundanese - 14
#   Madurese - 7.5
#   Malay - 7.5
# * Timor-Leste : 1066582 (2010)
# * Papua New Guinea : 7275324 (2011)
# * Iraq : 33330512 (2011)
#   Kurdish - 15
#   Arab - 75
#   Assyrian - 5
# * Jordan : 6249000 (2011)
#   Armenian - 1
#   Arab - 98
#   Circassian - 1
# * Kuwait : 2991580 (2010)
#   Arab - 35
#   Iranian - 4
#   South Asian - 9
#   Kuwaiti - 45
# * Saudi Arabia : 27136977 (2010)
#   Arab - 90
#   Afro-Asian - 10
# * Syria : 20866000 (2010)
#   Arab - 90.3
# * Lebanon : 4341092 (2010)
#   Armenian - 4
#   Arab - 95
# * West Bank : 2790331 (2014)
#   Jewish - 17
#   Palestinian Arab - 83
# * Japan : 127298000 (2013)
#   Japanese - 99.4
# * South Korea : 51141463 (2013)
# * Maldives : 341256 (2014)
# * Oman : 3623001 (2012)
# * United Arab Emirates : 8441537 (2010)
#   South Asian - 50
#   Emiri - 19
#   Arab Iranian - 23
# * Yemen : 24527000 (2012)
# * Philippines : 92337852 (2010)
#   Chinese - 1.5
#   Malay - 95.5
# * Qatar : 1699435 (2010)
#   Indian - 18
#   Pakistani - 18
#   Arab - 40
#   Iranian - 10
# * Singapore : 5076700 (2010)
#   Indian - 6.4
#   Chinese - 76.4
#   Malay - 14.9
# * Sri Lanka : 20263723 (2012)
#   Sinhalese - 74
#   Tamil - 18
#   Arab - 7
#   Vedda - 1
# * Taiwan : 23315822 (2012)
#   Chinese - 14
#   Taiwanese - 84
# * Anguilla : 13037 (2011)
#   Black - 90.1
#   Mulatto - 4.6
#   White - 3.7
# * Antigua and Barbuda : 81799 (2011)
# * Aruba : 101484 (2010)
#   European/Caribbean Amerindian - 80
# * Bahamas : 353658 (2010)
# * Barbados : 277821 (2010)
#   European - 4
#   African - 80
# * Belize : 312971 (2010)
#   Mestizo - 48.7
#   Creole - 24.9
#   Maya - 10.6
#   Garifuna - 6.1
# * Guatemala : 15073375 (2012)
#   Mestizo - 50
#   European - 10
#   Amerindian - 30.5
# * Mexico : 112336538 (2010)
#   Mestizo - 60
#   Amerindian - 30
#   European - 9
# * Bermuda : 64237 (2010)
#   Black - 54
#   White - 34.1
#   Mixed - 6.4
# * British Virgin Islands : 23161 (2001)
#   Black - 83.4
#   White - 7
#   Amerindian - 3.4
#   Mixed - 5.4
# * Canada : 35158304 (2013)
#   British Isles - 28
#   French - 23
#   European - 15
#   Inuit - 2
# * United States : 318857056 (2014)
#   European - 79.96
#   African - 12.85
#   Asian - 4.43
#   Amerindian - 0.97
# * Cayman Islands : 55691 (2013)
#   Black - 20
#   White - 20
#   Mixed - 40
# * Costa Rica : 4773119 (2014)
#   Mestizo - 74
#   European - 20
#   African - 3
#   Amerindian - 1
#   Chinese - 1
# * Nicaragua : 6071045 (2012)
#   Mestizo - 69
#   European - 17
#   African - 9
#   Amerindian - 5
# * Panama : 3405813 (2010)
#   Mestizo - 84
#   European - 10
#   Amerindian - 6
# * Cuba : 11167325 (2012)
#   European - 65.1
#   Mestizo - 12
#   Mulatto - 12
#   African - 10.1
# * Dominica : 70739 (2011)
#   Carib Indians - 100
# * Dominican Republic : 9445281 (2010)
#   Mulatto - 73
#   European - 16
#   African - 11
# * Haiti : 9896400 (2010)
#   African - 95
#   Mulatto - 3
#   European - 2
# * El Salvador : 6290420 (2013)
#   Mestizo - 90
#   European - 9
#   Amerindian - 1
# * Honduras : 8045990 (2010)
#   Mestizo - 90
#   Amerindian - 7
#   African - 2
#   European - 1
# * Greenland : 56370 (2013)
#   Danish - 14
#   Greenlander - 86
# * Grenada : 103328 (2011)
#   African - 100
# * Guadeloupe : 404635 (2011)
#   Chinese - 5
# * Jamaica : 2697983 (2011)
#   African - 76.3
#   Afro-European - 15.1
#   Afro-East Indian - 3
#   Afro-Chinese - 1.2
# * Martinique : 392291 (2011)
#   Chinese - 5
#   African-white-Indian - 90
# * Montserrat : 4922 (2011)
# * Curacao : 150563 (2011)
# * Sint Maarten : 37429 (2010)
# * Saint Martin : 37630 (2010)
# * Saint Barthelemy : 9072 (2010)
# * Colombia : 47661787 (2014)
#   Mestizo - 58
#   European - 20
#   Mulatto - 14
#   African - 4
#   black-Amerindian - 3
#   Amerindian - 1
# * Puerto Rico : 3725789 (2010)
#   White - 80.2
#   Black - 8
#   Amerindian - 0.4
#   Asian - 0.4
# * Saint Kitts and Nevis : 52352 (2010)
#   African - 100
# * Saint Lucia : 165595 (2010)
#   African - 90.3
#   East Indian - 3.2
# * Saint Pierre and Miquelon : 6312 (2010)
#   Basques Bretons - 100
# * Saint Vincent and the Grenadines : 109991 (2011)
# * Trinidad and Tobago : 1328019 (2011)
#   Chinese - 1
#   East Indian - 40
# * Turks and Caicos Islands : 31458 (2012)
#   African - 90
# * Virgin Islands : 106405 (2011)
# * American Samoa : 55519 (2010)
#   Caucasian - 2
#   Tongan - 4
#   Samoan - 89
# * Australia : 23135281 (2013)
#   European - 92
#   Asian - 7
# * Cook Islands : 17794 (2011)
#   Polynesian - 93.5
# * Fiji : 860559 (2010)
#   Indian - 46
#   Fijian - 49
# * French Polynesia : 268270 (2012)
#   French - 10
#   Chinese - 12
#   Polynesian - 78
# * Guam : 159358 (2010)
#   Chamorro - 37.1
#   Filipino - 26.3
# * Kiribati : 103058 (2010)
#   Micronesian - 100
# * Marshall Islands : 53158 (2011)
#   Micronesian - 100
# * Micronesia : 102843 (2010)
#   Polynesian - 100
# * Nauru : 10025 (2010)
#   Chinese - 8
#   European - 8
#   Nauruan - 58
#   Pacific Islander - 26
# * New Caledonia : 245580 (2009)
#   Vietnamese - 1.4
#   European - 34.1
#   Melanesian - 44.1
#   Wallisian - 9
#   Indonesian - 2.5
# * New Zealand : 4242048 (2013)
#   European - 56.8
#   Asian - 8
#   Maori - 7.4
#   Pacific Islander - 4.6
# * Niue : 1611 (2011)
#   Polynesian - 100
# * Norfolk Island : 2169 (2011)
# * Northern Mariana Islands : 53883 (2010)
#   Asian - 56.3
#   Pacific Islander - 36.3
#   Caucasian - 1.8
# * Palau : 17501 (2012)
# * Pitcairn : 66 (1991)
#   Bounty - 100
# * Solomon Islands : 526447 (2010)
#   Chinese - 0.3
#   European - 0.8
#   Polynesian - 4
#   Micronesian - 1.5
#   Melanesian - 93
# * Tonga : 103252 (2011)
# * Tuvalu : 9827 (2010)
#   Polynesian - 96
# * Tokelau : 1383 (2013)
#   Polynesian - 95
# * Vanuatu : 236299 (2010)
#   French - 4
#   Melanesian - 94
# * Wallis and Futuna : 12197 (2013)
#   Polynesian - 100
# * Samoa : 187820 (2011)
#   Europeans - 0.4
#   Samoan - 92.6
#   Euronesians - 7
# * Argentina : 42669500 (2014)
#   European - 97
# * Bolivia : 10027262 (2012)
#   Quechua - 30
#   Mestizo - 30
#   Aymara - 25
#   European - 15
# * Brazil : 202768562 (2014)
#   European - 53.7
#   Mulatto - 38.5
#   African - 6.2
# * Chile : 16341929 (2012)
#   Amerindian - 3
#   European - 95
# * Paraguay : 6672631 (2012)
#   Mestizo - 95
# * Uruguay : 3286314 (2011)
#   European - 88
#   Mestizo - 8
#   African - 4
# * Peru : 30135875 (2012)
#   Amerindian - 45
#   Mestizo - 37
#   European - 15
# * French Guiana : 237549 (2011)
#   Amerindian - 12
# * Guyana : 747884 (2012)
#   East Indian - 43.5
#   African - 30.2
#   Amerindian - 9.1
# * Suriname : 541638 (2012)
#   Hindustani - 37
#   Creole - 31
#   Javanese - 15.3
#   African - 10
#   Chinese - 2
#   Amerindian - 2
#   Europeans - 1
# * Venezuela : 28946101 (2011)
# * Ecuador : 14483499 (2010)
#   Mestizo - 65
#   Amerindian - 25
#   European - 7
#   African - 3
# * Falkland Islands : 2931 (2012)
#   Christian - 67.2
#   None - 31.5
# * Algeria : 37062820 (2010)
#   European - 1
#   Arab-Berber - 99
# * Libya : 6040612 (2010)
#   Berber Arab - 97
# * Mali : 13985961 (2010)
#   Mande - 50
#   Peuhl - 17
#   Voltaic - 12
#   Songhai - 6
#   Tuareg - 10
# * Mauritania : 3537368 (2013)
#   Maur - 30
#   Black Maur - 40
# * Morocco : 32901622 (2014)
#   Jewish - 0.2
#   Arab-Berber - 99.1
# * Niger : 17138707 (2012)
#   Fula - 8.5
#   Hausa - 56
#   Djerma - 22
#   Tuareg - 8
#   Beri Beri - 4.3
#   Gourmantche - 1.2
# * Tunisia : 10982754 (2014)
#   Jewish - 1
#   European - 1
#   Arab-Berber - 98
# * Western Sahara : 554795 (2013)
# * Angola : 24383301 (2014)
#   European - 1
#   Ovimbundu - 37
#   Kimbundu - 25
#   Bakongo - 13
# * Congo : 4001831 (2010)
# * Namibia : 2113077 (2011)
# * Zaire : 62191161 (2010)
#   Mangbetu-Azande - 45
# * Zambia : 13046508 (2010)
#   European - 1.1
#   African - 98.7
# * Benin : 9983884 (2013)
#   African - 99
# * Burkina Faso : 17322796 (2013)
#   Mossi - 24
# * Nigeria : 164294516 (2011)
#   African - 99
# * Togo : 6191155 (2010)
#   African - 99
#   European Syrian-Lebanese - 1
# * Botswana : 2038228 (2011)
#   Batswana - 95
#   Kgalagadi - 4
# * South Africa : 51770560 (2011)
#   Indian - 2.6
#   Colored - 8.6
# * Zimbabwe : 13061239 (2012)
#   Asian - 1
#   African - 98
# * Cote dIvoire : 22671331 (2014)
#   Malinke - 11
#   Baoule - 23
#   Bete - 18
#   Senoufou - 15
# * Ghana : 24658823 (2010)
#   European - 0.2
#   African - 99.8
# * Burundi : 8444784 (2010)
# * Rwanda : 10515973 (2012)
#   Hutu - 80
#   Tutsi - 19
#   Twa - 1
# * Tanzania : 44928923 (2012)
#   Bantu - 95
# * Cameroon : 19406100 (2010)
#   African - 13
#   Fulani - 10
#   Cameroon Highlanders - 31
#   Equatorial Bantu - 19
#   Kirdi - 11
#   Northwestern Bantu - 8
#   Eastern Nigritic - 7
# * Central African Republic : 4349921 (2010)
#   Baya - 34
#   Banda - 27
#   Sara - 10
#   Mandjia - 21
#   Mboum - 4
#   MBaka - 4
# * Chad : 11720781 (2010)
# * Equatorial Guinea : 696167 (2010)
# * Gabon : 1556222 (2010)
# * Cape Verde : 491875 (2010)
#   European - 1
#   African - 28
#   Creole - 71
# * Sudan : 35652002 (2010)
#   Arab - 70
#   Beja - 6
# * South Sudan : 8260490 (2008)
# * Comoros : 683081 (2010)
# * Guinea : 10628972 (2014)
#   Malinke - 30
#   Peuhl - 40
#   Soussou - 20
# * Liberia : 3957990 (2010)
#   African - 95
#   Americo-Liberians - 5
# * Djibouti : 834036 (2010)
#   Italian - 5
#   Afar - 35
#   Somali - 60
# * Eritrea : 5741159 (2010)
#   Tigrinya - 55
#   Tigre - 30
#   Saho - 4
#   Kunama - 2
#   Rashaida - 2
#   Bilen - 2
# * Ethiopia : 84320987 (2012)
#   Oromo - 34.5
#   Amhara - 26.9
#   Somali - 6.2
#   Tigraway - 6.1
#   Sidama - 4
#   Gurage - 2.5
#   Welaita - 2.3
#   Hadiya - 1.7
#   Afar - 1.7
# * Somalia : 9636173 (2010)
#   Somali - 85
# * Kenya : 40909194 (2010)
#   Arab - 1
#   Kikuyu - 22
#   Luhya - 14
#   Luo - 13
#   Kalenjin - 12
#   Kamba - 11
#   Kisii - 6
#   Meru - 6
# * Gambia : 1882450 (2013)
#   African - 99
# * Senegal : 13508715 (2013)
#   Fulani - 17
#   Wolof - 36
#   Diola - 9
#   Mandingo - 9
#   Serer - 17
#   Toucouleur - 9
#   European Lebanese - 1
# * Guinea-Bissau : 1586624 (2010)
#   European - 1
#   African - 99
# * Sierra Leone : 5751976 (2010)
#   Asian - 1
#   African - 99
# * Uganda : 34856813 (2014)
#   Rwanda - 6
#   Arab - 1
#   Baganda - 17
#   Karamojong - 12
#   Basogo - 8
#   Iteso - 8
#   Langi - 6
#   Bagisu - 5
#   Acholi - 4
#   Lugbara - 4
#   Bunyoro - 3
#   Batobo - 3
# * Lesotho : 2008921 (2010)
#   Sotho - 99.7
# * Madagascar : 21842167 (2013)
# * Malawi : 15013694 (2010)
# * Mozambique : 23700715 (2012)
#   European - 0.06
#   Indian - 0.08
#   Euro-African - 0.2
# * Mauritius : 1237091 (2011)
#   Creole - 27
#   Indo-Mauritian - 68
#   Sino-Mauritian - 3
#   Franco-Mauritian - 2
# * Mayotte : 212645 (2011)
# * Swaziland : 1193148 (2010)
#   European - 3
#   African - 97
# * Reunion : 828581 (2011)
# * Saint Helena : 5663 (2014)
#   African descent - 50
#   White - 25
#   Chinese - 25
# * Sao Tome and Principe : 187356 (2012)
#   European - 100
# * Seychelles : 90945 (2010)
#   Seychellois - 100
